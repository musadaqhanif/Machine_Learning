# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Dell\Desktop\Panda\AirQualityUCI.csv", sep=';')

# %%
df = df.rename(columns={'CO(GT)': 'CO', 'PT08.S1(CO)': 'PT08_CO', 'NMHC(GT)': 'NMHC', 'C6H6(GT)': 'C6H6', 'PT08.S2(NMHC)': 'PT08_NMHC', 'NOx(GT)': 'NOx', 'PT08.S3(NOx)': 'PT08_NOx', 'NO2(GT)': 'NO2', 'PT08.S4(NO2)': 'PT08_NO2', 'PT08.S5(O3)': 'PT08_O3'})
print(df.head())
# Out:
#          Date      Time   CO  PT08_CO   NMHC  C6H6  PT08_NMHC    NOx  \
# 0  10/03/2004  18.00.00  2,6   1360.0  150.0  11,9     1046.0  166.0
# 1  10/03/2004  19.00.00    2   1292.0  112.0   9,4      955.0  103.0
# 2  10/03/2004  20.00.00  2,2   1402.0   88.0   9,0      939.0  131.0
# 3  10/03/2004  21.00.00  2,2   1376.0   80.0   9,2      948.0  172.0
# 4  10/03/2004  22.00.00  1,6   1272.0   51.0   6,5      836.0  131.0
#
#    PT08_NOx    NO2  PT08_NO2  PT08_O3     T    RH      AH  Unnamed: 15  \
# 0    1056.0  113.0    1692.0   1268.0  13,6  48,9  0,7578          NaN
# 1    1174.0   92.0    1559.0    972.0  13,3  47,7  0,7255          NaN
# 2    1140.0  114.0    1555.0   1074.0  11,9  54,0  0,7502          NaN
# 3    1092.0  122.0    1584.0   1203.0  11,0  60,0  0,7867          NaN
# 4    1205.0  116.0    1490.0   1110.0  11,2  59,6  0,7888          NaN
#
#    Unnamed: 16
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df = df.drop(['Unnamed: 15','Unnamed: 16'],axis=1)
print(df.head())
# Out:
#          Date      Time   CO  PT08_CO   NMHC  C6H6  PT08_NMHC    NOx  \
# 0  10/03/2004  18.00.00  2,6   1360.0  150.0  11,9     1046.0  166.0
# 1  10/03/2004  19.00.00    2   1292.0  112.0   9,4      955.0  103.0
# 2  10/03/2004  20.00.00  2,2   1402.0   88.0   9,0      939.0  131.0
# 3  10/03/2004  21.00.00  2,2   1376.0   80.0   9,2      948.0  172.0
# 4  10/03/2004  22.00.00  1,6   1272.0   51.0   6,5      836.0  131.0
#
#    PT08_NOx    NO2  PT08_NO2  PT08_O3     T    RH      AH
# 0    1056.0  113.0    1692.0   1268.0  13,6  48,9  0,7578
# 1    1174.0   92.0    1559.0    972.0  13,3  47,7  0,7255
# 2    1140.0  114.0    1555.0   1074.0  11,9  54,0  0,7502
# 3    1092.0  122.0    1584.0   1203.0  11,0  60,0  0,7867
# 4    1205.0  116.0    1490.0   1110.0  11,2  59,6  0,7888

# %%
print(df.to_string())
# Out:
#             Date      Time      CO  PT08_CO    NMHC    C6H6  PT08_NMHC     NOx  PT08_NOx    NO2  PT08_NO2  PT08_O3     T    RH      AH
# 0     10/03/2004  18.00.00     2,6   1360.0   150.0    11,9     1046.0   166.0    1056.0  113.0    1692.0   1268.0  13,6  48,9  0,7578
# 1     10/03/2004  19.00.00       2   1292.0   112.0     9,4      955.0   103.0    1174.0   92.0    1559.0    972.0  13,3  47,7  0,7255
# 2     10/03/2004  20.00.00     2,2   1402.0    88.0     9,0      939.0   131.0    1140.0  114.0    1555.0   1074.0  11,9  54,0  0,7502
# 3     10/03/2004  21.00.00     2,2   1376.0    80.0     9,2      948.0   172.0    1092.0  122.0    1584.0   1203.0  11,0  60,0  0,7867
# 4     10/03/2004  22.00.00     1,6   1272.0    51.0     6,5      836.0   131.0    1205.0  116.0    1490.0   1110.0  11,2  59,6  0,7888
# 5     10/03/2004  23.00.00     1,2   1197.0    38.0     4,7      750.0    89.0    1337.0   96.0    1393.0    949.0  11,2  59,2  0,7848
# ...

# %%
# df.to_csv(r"C:\Users\Dell\Desktop\Panda\AirQualityUCI.csv")

# %%
df.head(10)
# Out:
#          Date      Time   CO  PT08_CO   NMHC  C6H6  PT08_NMHC    NOx  \
# 0  10/03/2004  18.00.00  2,6   1360.0  150.0  11,9     1046.0  166.0
# 1  10/03/2004  19.00.00    2   1292.0  112.0   9,4      955.0  103.0
# 2  10/03/2004  20.00.00  2,2   1402.0   88.0   9,0      939.0  131.0
# 3  10/03/2004  21.00.00  2,2   1376.0   80.0   9,2      948.0  172.0
# 4  10/03/2004  22.00.00  1,6   1272.0   51.0   6,5      836.0  131.0
# 5  10/03/2004  23.00.00  1,2   1197.0   38.0   4,7      750.0   89.0
# 6  11/03/2004  00.00.00  1,2   1185.0   31.0   3,6      690.0   62.0
# 7  11/03/2004  01.00.00    1   1136.0   31.0   3,3      672.0   62.0
# 8  11/03/2004  02.00.00  0,9   1094.0   24.0   2,3      609.0   45.0
# 9  11/03/2004  03.00.00  0,6   1010.0   19.0   1,7      561.0 -200.0
#
#    PT08_NOx    NO2  PT08_NO2  PT08_O3     T    RH      AH
# 0    1056.0  113.0    1692.0   1268.0  13,6  48,9  0,7578
# 1    1174.0   92.0    1559.0    972.0  13,3  47,7  0,7255
# ...

# %%
df.describe()
# Out:
#            PT08_CO         NMHC    PT08_NMHC          NOx     PT08_NOx  \
# count  9357.000000  9357.000000  9357.000000  9357.000000  9357.000000
# mean   1048.990061  -159.090093   894.595276   168.616971   794.990168
# std     329.832710   139.789093   342.333252   257.433866   321.993552
# min    -200.000000  -200.000000  -200.000000  -200.000000  -200.000000
# 25%     921.000000  -200.000000   711.000000    50.000000   637.000000
# 50%    1053.000000  -200.000000   895.000000   141.000000   794.000000
# 75%    1221.000000  -200.000000  1105.000000   284.000000   960.000000
# max    2040.000000  1189.000000  2214.000000  1479.000000  2683.000000
#
#                NO2     PT08_NO2      PT08_O3
# count  9357.000000  9357.000000  9357.000000
# mean     58.148873  1391.479641   975.072032
# std     126.940455   467.210125   456.938184
# min    -200.000000  -200.000000  -200.000000
# 25%      53.000000  1185.000000   700.000000
# 50%      96.000000  1446.000000   942.000000
# ...

# %%
df.shape
# Out:
# (9471, 15)

# %%
df.isnull().sum()
# Out:
# Date         114
# Time         114
# CO           114
# PT08_CO      114
# NMHC         114
# C6H6         114
# PT08_NMHC    114
# NOx          114
# PT08_NOx     114
# NO2          114
# PT08_NO2     114
# PT08_O3      114
# T            114
# RH           114
# AH           114
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Date         0
# Time         0
# CO           0
# PT08_CO      0
# NMHC         0
# C6H6         0
# PT08_NMHC    0
# NOx          0
# PT08_NOx     0
# NO2          0
# PT08_NO2     0
# PT08_O3      0
# T            0
# RH           0
# AH           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 827 entries, 0 to 1230
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       827 non-null    datetime64[ns]
#  1   Time       827 non-null    object
#  2   CO         827 non-null    object
#  3   PT08_CO    827 non-null    object
#  4   NMHC       827 non-null    object
#  5   C6H6       827 non-null    object
#  6   PT08_NMHC  827 non-null    object
#  7   NOx        827 non-null    object
#  8   PT08_NOx   827 non-null    object
#  9   NO2        827 non-null    object
#  10  PT08_NO2   827 non-null    object
#  11  PT08_O3    827 non-null    object
#  12  T          827 non-null    object
#  13  RH         827 non-null    object
#  14  AH         827 non-null    object
# dtypes: datetime64[ns](1), object(14)
# memory usage: 103.4+ KB

# %%
#df["Date"]=pd.to_datetime(df["Date"],dayfirst=True)
#df["Time"]=pd.to_datetime(df["Time"],format= '%H.%M.%S' ).dt.time

# %%
df['CO'] = df['CO'].astype(float)
df['C6H6'] = df['C6H6'].astype(float)
df['T'] = df['T'].astype(float)
df['RH'] = df['RH'].astype(float)

# %%
df['PT08_CO'] = df['PT08_CO'].astype(float)
df['NMHC'] = df['NMHC'].astype(float)
df['NOx'] = df['NOx'].astype(float)
df['PT08_NOx'] = df['PT08_NOx'].astype(float)
df['NO2'] = df['NO2'].astype(float)
df['PT08_NO2'] = df['PT08_NO2'].astype(float)
df['PT08_O3'] = df['PT08_O3'].astype(float)

# %%
df['AH'] = df['AH'].astype(float)
df['PT08_NMHC'] = df['PT08_NMHC'].astype(int)

# %%
#df.to_csv(r"C:\Users\Dell\Desktop\Panda\AirQualityUCI.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 827 entries, 0 to 1230
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       827 non-null    datetime64[ns]
#  1   Time       827 non-null    object
#  2   CO         827 non-null    float64
#  3   PT08_CO    827 non-null    float64
#  4   NMHC       827 non-null    float64
#  5   C6H6       827 non-null    float64
#  6   PT08_NMHC  827 non-null    int32
#  7   NOx        827 non-null    float64
#  8   PT08_NOx   827 non-null    float64
#  9   NO2        827 non-null    float64
#  10  PT08_NO2   827 non-null    float64
#  11  PT08_O3    827 non-null    float64
#  12  T          827 non-null    float64
#  13  RH         827 non-null    float64
#  14  AH         827 non-null    float64
# dtypes: datetime64[ns](1), float64(12), int32(1), object(1)
# memory usage: 100.1+ KB

# %%
df.head(10)
# Out:
#          Date      Time   CO PT08_CO   NMHC  C6H6  PT08_NMHC    NOx PT08_NOx  \
# 0  2004-03-10  18:00:00  2.6  1360.0  150.0  11.9       1046  166.0   1056.0
# 1  2004-03-10  19:00:00  2.0  1292.0  112.0   9.4        955  103.0   1174.0
# 2  2004-03-10  20:00:00  2.2  1402.0   88.0   9.0        939  131.0   1140.0
# 3  2004-03-10  21:00:00  2.2  1376.0   80.0   9.2        948  172.0   1092.0
# 4  2004-03-10  22:00:00  1.6  1272.0   51.0   6.5        836  131.0   1205.0
# 5  2004-03-10  23:00:00  1.2  1197.0   38.0   4.7        750   89.0   1337.0
# 6  2004-03-11  00:00:00  1.2  1185.0   31.0   3.6        690   62.0   1462.0
# 7  2004-03-11  01:00:00  1.0  1136.0   31.0   3.3        672   62.0   1453.0
# 8  2004-03-11  02:00:00  0.9  1094.0   24.0   2.3        609   45.0   1579.0
# 11 2004-03-11  05:00:00  0.7  1066.0    8.0   1.1        512   16.0   1918.0
#
#       NO2 PT08_NO2 PT08_O3     T    RH      AH
# 0   113.0   1692.0  1268.0  13.6  48.9  0.7578
# ...

# %%
df['CO'].value_counts()
# Out:
# CO
# 1.9    31
# 1.5    30
# 2.0    30
# 1.1    29
# 1.4    29
#        ..
# 6.3     1
# 7.3     1
# 6.4     1
# 6.0     1
# 7.2     1
# Name: count, Length: 71, dtype: int64

# %%
df.replace(to_replace=-200,value=pd.NA,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 827 entries, 0 to 1230
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       827 non-null    datetime64[ns]
#  1   Time       827 non-null    object
#  2   CO         827 non-null    float64
#  3   PT08_CO    827 non-null    float64
#  4   NMHC       827 non-null    float64
#  5   C6H6       827 non-null    float64
#  6   PT08_NMHC  827 non-null    int32
#  7   NOx        827 non-null    float64
#  8   PT08_NOx   827 non-null    float64
#  9   NO2        827 non-null    float64
#  10  PT08_NO2   827 non-null    float64
#  11  PT08_O3    827 non-null    float64
#  12  T          827 non-null    float64
#  13  RH         827 non-null    float64
#  14  AH         827 non-null    float64
# dtypes: datetime64[ns](1), float64(12), int32(1), object(1)
# memory usage: 100.1+ KB

# %%
df.dropna(inplace=True)

# %%
df['CO'].value_counts()
# Out:
# CO
# 1.9    31
# 1.5    30
# 2.0    30
# 1.1    29
# 1.4    29
#        ..
# 6.3     1
# 7.3     1
# 6.4     1
# 6.0     1
# 7.2     1
# Name: count, Length: 71, dtype: int64

# %%
data=df.drop(["Date","Time"],axis=1)
correlation=data.corr()
plt.figure(figsize=(12,8))
sns.heatmap(correlation,annot=True,cmap="coolwarm",fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
data=df.drop(["Date","Time"],axis=1)
data.corr()
# Out:
#                  CO   PT08_CO      NMHC      C6H6  PT08_NMHC       NOx  \
# CO         1.000000  0.936261  0.887167  0.972660   0.958426  0.951342
# PT08_CO    0.936261  1.000000  0.781747  0.931368   0.936346  0.922885
# NMHC       0.887167  0.781747  1.000000  0.897928   0.875061  0.811182
# C6H6       0.972660  0.931368  0.897928  1.000000   0.984834  0.927304
# PT08_NMHC  0.958426  0.936346  0.875061  0.984834   1.000000  0.926633
# NOx        0.951342  0.922885  0.811182  0.927304   0.926633  1.000000
# PT08_NOx  -0.823728 -0.829577 -0.774237 -0.848850  -0.910651 -0.814297
# NO2        0.861432  0.866579  0.728052  0.846743   0.885023  0.857425
# PT08_NO2   0.939921  0.945020  0.848489  0.960811   0.957883  0.912724
# PT08_O3    0.882943  0.935011  0.761905  0.896978   0.909100  0.893381
# T          0.318261  0.324815  0.366976  0.418409   0.445615  0.238395
# RH        -0.105157 -0.039570 -0.160257 -0.178410  -0.193333 -0.041975
# ...

# %%
plt.figure(figsize=(30,10))
df['Time'] = df['Time'].astype(str)
sns.scatterplot(x="Time",y="CO",data=df)
plt.show()

# %%
plt.figure(figsize=(30,10))
df['Time'] = df['Time'].astype(str)
sns.scatterplot(x="Time",y="NMHC",data=df)
plt.show()

# %%
plt.figure(figsize=(30,15))
df['Time'] = df['Time'].astype(str)
sns.scatterplot(x="Time",y="C6H6",data=df)
plt.show()

# %%
plt.figure(figsize=(30,15))
df['Time'] = df['Time'].astype(str)
sns.scatterplot(x="Time",y="NOx",data=df)
plt.show()

# %%
plt.figure(figsize=(30,15))
df['Time'] = df['Time'].astype(str)
sns.scatterplot(x="Time",y="NO2",data=df)
plt.show()

# %%
"""CO level is highest at 8 am  in morning and 7 to 8pm at night.

NhMC level is highest at 8 am in morning and 7 pm at night.


C6H6 level is highest at 8 to 9 am in morning and 7 pm at night.


NOx level is highest at 9 am in morning and 7 pm at night.


NO2 level is highest at 3 pm in evening and 7 pm at night.

# Recomendations
1-Almost all of the parameters are at peak level in morning from 8 to 9 and at 7 pm at night .
At these hours there is a lot of traffic of schools , factories, offices so it is clear that to
improve air quality we should control the traffic at these hours
"""
