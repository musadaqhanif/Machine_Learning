# %%
import pandas as pd

# %%
fd=pd.read_csv(r"C:\Users\Dell\Desktop\8836201-6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv")

# %%
print(fd)
# Out:
#      Unnamed: 0  sepal.length  sepal.width  petal.length  petal.width  \
# 0             0           5.1          3.5           1.4          0.2
# 1             1           4.9          3.0           1.4          0.2
# 2             2           4.7          3.2           1.3          0.2
# 3             3           4.6          3.1           1.5          0.2
# 4             4           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         145           6.7          3.0           5.2          2.3
# 146         146           6.3          2.5           5.0          1.9
# 147         147           6.5          3.0           5.2          2.0
# 148         148           6.2          3.4           5.4          2.3
# 149         149           5.9          3.0           5.1          1.8
#
#        variety  petal_area  sepal Area  length ratio  width ratio
# ...

# %%
fd["sepal Area"] = fd["sepal.length"] * fd["sepal.width"]
fd["petal Area"] = fd["petal.length"] * fd["petal.width"]

# %%
print(fd)
# Out:
#      Unnamed: 0  sepal.length  sepal.width  petal.length  petal.width  \
# 0             0           5.1          3.5           1.4          0.2
# 1             1           4.9          3.0           1.4          0.2
# 2             2           4.7          3.2           1.3          0.2
# 3             3           4.6          3.1           1.5          0.2
# 4             4           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         145           6.7          3.0           5.2          2.3
# 146         146           6.3          2.5           5.0          1.9
# 147         147           6.5          3.0           5.2          2.0
# 148         148           6.2          3.4           5.4          2.3
# 149         149           5.9          3.0           5.1          1.8
#
#        variety  petal_area  sepal Area  length ratio  width ratio  petal Area
# ...

# %%
fd.to_csv(r"C:\Users\Dell\Desktop\8836201-6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv",index="False")

# %%
fd["length ratio"]=fd["petal.length"]/fd["sepal.length"]
fd["width ratio"]=fd["petal.width"]/fd["sepal.width"]

# %%
print(fd.to_string())
# Out:
#      Unnamed: 0  sepal.length  sepal.width  petal.length  petal.width     variety  petal_area  sepal Area  length ratio  width ratio  petal Area
# 0             0           5.1          3.5           1.4          0.2      Setosa        0.28       17.85      0.274510     0.057143        0.28
# 1             1           4.9          3.0           1.4          0.2      Setosa        0.28       14.70      0.285714     0.066667        0.28
# 2             2           4.7          3.2           1.3          0.2      Setosa        0.26       15.04      0.276596     0.062500        0.26
# 3             3           4.6          3.1           1.5          0.2      Setosa        0.30       14.26      0.326087     0.064516        0.30
# 4             4           5.0          3.6           1.4          0.2      Setosa        0.28       18.00      0.280000     0.055556        0.28
# ...

# %%
fd.to_csv(r"C:\Users\Dell\Desktop\8836201-6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv",index="False")

# %%
import pandas as pd
fd=pd.read_csv(r"C:\Users\Dell\Desktop\8836201-6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv")

# %%
petal_area_Setosa = fd.loc[0:49,"petal_area"]
petal_area_Versicolor=fd.loc[50:99,"petal_area"]
petal_area_Virginica=fd.loc[100:149,"petal_area"]
sepal_area_Setosa=fd.loc[0:49,"sepal Area"]
sepal_area_Versicolor=fd.loc[50:99,"sepal Area"]
sepal_area_Virginica=fd.loc[100:149,"sepal Area"]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(petal_area_Setosa ,sepal_area_Setosa)
plt.xlabel("petal_area_Setosa")
plt.ylabel("sepal_area_Setosa")
plt.show()

# %%
plt.scatter(petal_area_Versicolor ,sepal_area_Versicolor)
plt.xlabel("petal_area_Versicolor")
plt.ylabel("sepal_area_Versicolor")
plt.show()

# %%
plt.scatter(petal_area_Virginica,sepal_area_Virginica)
plt.xlabel("petal_area_Virginica")
plt.ylabel("sepal_area_Virginica")
plt.show()

# %%
plt.bar(petal_area_Setosa ,sepal_area_Setosa)
# Out:
# <BarContainer object of 50 artists>

# %%
plt.bar(petal_area_Versicolor ,sepal_area_Versicolor)
# Out:
# <BarContainer object of 50 artists>

# %%
plt.bar(petal_area_Virginica,sepal_area_Virginica)
# Out:
# <BarContainer object of 50 artists>

# %%
fd["Area_ratio"]=fd["petal_area"]/fd["sepal Area"]

# %%
fd.to_csv(r"C:\Users\Dell\Desktop\8836201-6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv",index="False")

# %%
print(fd.to_string())
# Out:
#      Unnamed: 0.1  Unnamed: 0  sepal.length  sepal.width  petal.length  petal.width     variety  petal_area  sepal Area  length ratio  width ratio  petal Area  Area_ratio
# 0               0           0           5.1          3.5           1.4          0.2      Setosa        0.28       17.85      0.274510     0.057143        0.28    0.015686
# 1               1           1           4.9          3.0           1.4          0.2      Setosa        0.28       14.70      0.285714     0.066667        0.28    0.019048
# 2               2           2           4.7          3.2           1.3          0.2      Setosa        0.26       15.04      0.276596     0.062500        0.26    0.017287
# 3               3           3           4.6          3.1           1.5          0.2      Setosa        0.30       14.26      0.326087     0.064516        0.30    0.021038
# ...
