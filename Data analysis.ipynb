# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
video_game=pd.read_csv(r"C:\Users\Dell\Desktop\Panda\vgsales.csv")

# %%
video_game.dropna(inplace=True)

# %%
video_game.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
print(video_game.isnull().sum())
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
video_game.dropna(inplace=True)
video_game.to_csv(r"C:\Users\Dell\Desktop\Panda\vgsales.csv")

# %%
print(video_game.isnull().sum())
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
video_game.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16291.000000  16291.000000  16291.000000  16291.000000  16291.000000
# mean    8290.190228   2006.405561      0.265647      0.147731      0.078833
# std     4792.654450      5.832412      0.822432      0.509303      0.311879
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4132.500000   2003.000000      0.000000      0.000000      0.000000
# 50%     8292.000000   2007.000000      0.080000      0.020000      0.000000
# 75%    12439.500000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16291.000000  16291.000000
# mean       0.048426      0.540910
# std        0.190083      1.567345
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.480000
# ...

# %%
plt.figure(figsize=(20, 10)) 
sns.scatterplot(x='Platform', y='Global_Sales',data=video_game)
plt.show()

# %%
plt.figure(figsize=(20, 10)) 
sns.scatterplot(x='Genre', y='Global_Sales',data=video_game)
plt.show()

# %%
top_publisher=video_game.groupby("Publisher")["Global_Sales"].sum().nlargest(10)
plt.figure(figsize=(10,6))
top_publisher.plot(kind="bar",rot=90)
plt.xlabel("Publisher")
plt.xlabel("Global_Sales")
plt.title("Top 10 publishers by global sales")
plt.show()

# %%
   # Obsevation for Global sales 
# wii platform has highest video games sales globally 
# sports Genre has highest video games sales globally
# Nintendo publisher has highest video games sales globally
   # Recomendations for Global sale
# TO Improve video games sales globally  from above discussion it is highly recommended 
#that games should be published on wii platform  by Nintendo publisher and genre of games should be sports

# %%
 # video games analysis ended

# %%
data=pd.read_csv(r"C:\Users\Dell\Desktop\Panda\2019.csv")

# %%
print(data.isnull().sum())
# Out:
# Unnamed: 0.1                    0
# Unnamed: 0                      0
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %%
column_means = data.drop(columns='Country or region').mean()

# %%
for column in data.columns:
    if column != 'Country or region':
        # Replace 0 values with column mean
        data[column] = data[column].replace(0, column_means[column])

# %%
data.to_csv(r"C:\Users\Dell\Desktop\Panda\2019.csv")

# %%
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  Overall rank Country or region  Score  \
# 0          77.5        77.5             1           Finland  7.769
# 1           1.0         1.0             2           Denmark  7.600
# 2           2.0         2.0             3            Norway  7.554
# 3           3.0         3.0             4           Iceland  7.494
# 4           4.0         4.0             5       Netherlands  7.488
#
#    GDP per capita  Social support  Healthy life expectancy  \
# 0           1.340           1.587                    0.986
# 1           1.383           1.573                    0.996
# 2           1.488           1.582                    1.028
# 3           1.380           1.624                    1.026
# 4           1.396           1.522                    0.999
#
#    Freedom to make life choices  Generosity  Perceptions of corruption
# 0                         0.596       0.153                      0.393
# ...

# %%
data.describe()
# Out:
#        Unnamed: 0.1  Unnamed: 0  Overall rank       Score  GDP per capita  \
# count    156.000000  156.000000    156.000000  156.000000      156.000000
# mean      77.996795   77.996795     78.500000    5.407096        0.910950
# std       44.743733   44.743733     45.177428    1.113120        0.391656
# min        1.000000    1.000000      1.000000    2.853000        0.026000
# 25%       39.750000   39.750000     39.750000    4.544500        0.617000
# 50%       77.750000   77.750000     78.500000    5.379500        0.960000
# 75%      116.250000  116.250000    117.250000    6.184500        1.232500
# max      155.000000  155.000000    156.000000    7.769000        1.684000
#
#        Social support  Healthy life expectancy  Freedom to make life choices  \
# count      156.000000               156.000000                    156.000000
# mean         1.216563                 0.729893                      0.395087
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0.1                  156 non-null    float64
#  1   Unnamed: 0                    156 non-null    float64
#  2   Overall rank                  156 non-null    int64
#  3   Country or region             156 non-null    object
#  4   Score                         156 non-null    float64
#  5   GDP per capita                156 non-null    float64
#  6   Social support                156 non-null    float64
#  7   Healthy life expectancy       156 non-null    float64
#  8   Freedom to make life choices  156 non-null    float64
#  9   Generosity                    156 non-null    float64
#  10  Perceptions of corruption     156 non-null    float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 13.5+ KB

# %%
top_countries=data.groupby("Country or region")["Overall rank"].sum().nsmallest(5)
plt.figure(figsize=(10,6))
top_countries.plot(kind="bar",rot=45,color="red")
plt.xlabel("Country or region")
plt.ylabel("rank")
plt.title("Rank of countries wrt Highest Happines Score")
plt.show()
top_countries=data.groupby("Country or region")["Overall rank"].sum().nlargest(5)
plt.figure(figsize=(10,6))
top_countries.plot(kind="bar",rot=45,color="red")
plt.xlabel("Country or region")
plt.ylabel("rank")
plt.title("Rank of countries wrt lowest Happines Score")
plt.show()

# %%
top_countries=data.groupby("Country or region")["GDP per capita"].sum().nlargest(5)
plt.figure(figsize=(10,6))
top_countries.plot(kind="bar",rot=45,color="red")
plt.xlabel("Country or region")
plt.ylabel("rank")
plt.title("Rank of countries wrt Highes GDP Score")
plt.show()
top_countries=data.groupby("Country or region")["GDP per capita"].sum().nsmallest(5)
plt.figure(figsize=(10,6))
top_countries.plot(kind="bar",rot=45,color="red")
plt.xlabel("Country or region")
plt.ylabel("rank")
plt.title("Rank of countries wrt lowest GDP Score")
plt.show()

# %%
top_countries=data.groupby("Country or region")["Social support"].sum().nlargest(5)
plt.figure(figsize=(10,6))
top_countries.plot(kind="bar",rot=45,color="red")
plt.xlabel("Country or region")
plt.ylabel("rank")
plt.title("Rank of countries wrt Highest Social support Score")
plt.show()
top_countries=data.groupby("Country or region")["Social support"].sum().nsmallest(5)
plt.figure(figsize=(10,6))
top_countries.plot(kind="bar",rot=45,color="red")
plt.xlabel("Country or region")
plt.ylabel("rank")
plt.title("Rank of countries wrt lowest Social support Score")
plt.show()

# %%
top_countries=data.groupby("Country or region")["Freedom to make life choices"].sum().nlargest(5)
plt.figure(figsize=(10,6))
top_countries.plot(kind="bar",rot=45,color="red")
plt.xlabel("Country or region")
plt.ylabel("rank")
plt.title("Rank of countries wrt Highest Freedom to make life choices Score")
plt.show()
top_countries=data.groupby("Country or region")["Freedom to make life choices"].sum().nsmallest(5)
plt.figure(figsize=(10,6))
top_countries.plot(kind="bar",rot=45,color="red")
plt.xlabel("Country or region")
plt.ylabel("rank")
plt.title("Rank of countries wrt lowest Freedom to make life choices Score")
plt.show()

# %%
top_countries=data.groupby("Country or region")["Generosity"].sum().nlargest(5)
plt.figure(figsize=(10,6))
top_countries.plot(kind="bar",rot=45,color="red")
plt.xlabel("Country or region")
plt.ylabel("rank")
plt.title("Rank of countries wrt Highest Generosity Score")
plt.show()
top_countries=data.groupby("Country or region")["Generosity"].sum().nsmallest(5)
plt.figure(figsize=(10,6))
top_countries.plot(kind="bar",rot=45,color="red")
plt.xlabel("Country or region")
plt.ylabel("rank")
plt.title("Rank of countries wrt lowest Generosity Score")
plt.show()

# %%
top_countries=data.groupby("Country or region")["Perceptions of corruption"].sum().nlargest(5)
plt.figure(figsize=(10,6))
top_countries.plot(kind="bar",rot=45,color="red")
plt.xlabel("Country or region")
plt.ylabel("rank")
plt.title("Rank of countries wrt Highest Perceptions of corruption Score")
plt.show()
top_countries=data.groupby("Country or region")["Perceptions of corruption"].sum().nsmallest(5)
plt.figure(figsize=(10,6))
top_countries.plot(kind="bar",rot=45,color="red")
plt.xlabel("Country or region")
plt.ylabel("rank")
plt.title("Rank of countries wrt lowest Perceptions of corruption Score")
plt.show()

# %%
top_countries=data.groupby("Country or region")["Healthy life expectancy"].sum().nlargest(5)
plt.figure(figsize=(10,6))
top_countries.plot(kind="bar",rot=45,color="red")
plt.xlabel("Country or region")
plt.ylabel("rank")
plt.title("Rank of countries wrt Highes Healthy life expectancy Score")
plt.show()
top_countries=data.groupby("Country or region")["Healthy life expectancy"].sum().nsmallest(5)
plt.figure(figsize=(10,6))
top_countries.plot(kind="bar",rot=45,color="red")
plt.xlabel("Country or region")
plt.ylabel("rank")
plt.title("Rank of countries wrt lowest Healthy life expectancy Score")
plt.show()

# %%
     
"""
# Analysis of Happiness Report
# Finland has highest Happines rate in the world 
# South soudan has lowest happiness rate in the world

Top five countries that has highest GDP rate are not in the list of top 5 Happiest countries 
So it has no strong relation with Happiness score

Top five countries that has highest Social Support Score rate are in the list of top 5 Happiest countries 
So it has  strong relation with Happiness score

Top five countries that has highest index  of Freedom to make life choices  are in the list of top 5 Happiest countries 
So it has strong relation with Happiness score

Top five countries that has highest Generosity rate are not in the list of top 5 Happiest countries 
So it has no strong relation with Happiness score

Top five countries that has highest Corruption rate are  in the list of top 5 Happiest countries 
So it has no strong relation with Happiness score

Top five countries that has highest GDP rate are not in the list of top 5 Happiest countries 
So it has no strong relation with Happiness score

Top five countries that has highest Health life Expectancy  rate are not in the list of top 5 Happiest countries 
So it has no strong relation with Happiness score

         # Recommendations to improve Happiness score
         
Following  parameters must be increased to improve Happiness rate beacuse 
they has strong  relation with Happiness rate

1-Freedom to make life choices
2-Social support
"""
# Out:
# '\n# Analysis of Happiness Report\n# Finland has highest Happines rate in the world \n# South soudan has lowest happiness rate in the world\n\nTop five countries that has highest GDP rate are not in the list of top 5 Happiest countries \nSo it has no strong relation with Happiness score\n\nTop five countries that has highest Social Support Score rate are in the list of top 5 Happiest countries \nSo it has  strong relation with Happiness score\n\nTop five countries that has highest index  of Freedom to make life choices  are in the list of top 5 Happiest countries \nSo it has strong relation with Happiness score\n\nTop five countries that has highest Generosity rate are not in the list of top 5 Happiest countries \nSo it has no strong relation with Happiness score\n\nTop five countries that has highest Corruption rate are  in the list of top 5 Happiest countries \nSo it has no strong relation with Happiness score\n\nTop five countries that has highest GDP rate are not in the list of t
# ...

# %%
#  Analysis of Happiness Report Ended

# %%
df = pd.read_csv(r"C:\Users\Dell\Desktop\Panda\AirQualityUCI.csv", sep=';')

# %%
df = df.rename(columns={'CO(GT)': 'CO', 'PT08.S1(CO)': 'PT08_CO', 'NMHC(GT)': 'NMHC', 'C6H6(GT)': 'C6H6', 'PT08.S2(NMHC)': 'PT08_NMHC', 'NOx(GT)': 'NOx', 'PT08.S3(NOx)': 'PT08_NOx', 'NO2(GT)': 'NO2', 'PT08.S4(NO2)': 'PT08_NO2', 'PT08.S5(O3)': 'PT08_O3'})
print(df.head())
# Out:
#   ,Date,Time,CO,PT08_CO,NMHC,C6H6,PT08_NMHC,NOx,PT08_NOx,NO2,PT08_NO2,PT08_O3,T,RH,AH
# 0  0,2004-03-10,18:00:00,2.6,1360.0,150.0,11.9,10...
# 1  1,2004-03-10,19:00:00,2.0,1292.0,112.0,9.4,955...
# 2  2,2004-03-10,20:00:00,2.2,1402.0,88.0,9.0,939,...
# 3  3,2004-03-10,21:00:00,2.2,1376.0,80.0,9.2,948,...
# 4  4,2004-03-10,22:00:00,1.6,1272.0,51.0,6.5,836,...

# %%
df = df.drop(['Unnamed: 15','Unnamed: 16'],axis=1)
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df = df.drop(['Unnamed: 15','Unnamed: 16'],axis=1)
#       2 print(df.head())
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
# ...

# %%
print(df.to_string())
# Out:
#                        ,Date,Time,CO,PT08_CO,NMHC,C6H6,PT08_NMHC,NOx,PT08_NOx,NO2,PT08_NO2,PT08_O3,T,RH,AH
# 0       0,2004-03-10,18:00:00,2.6,1360.0,150.0,11.9,1046,166.0,1056.0,113.0,1692.0,1268.0,13.6,48.9,0.7578
# 1           1,2004-03-10,19:00:00,2.0,1292.0,112.0,9.4,955,103.0,1174.0,92.0,1559.0,972.0,13.3,47.7,0.7255
# 2          2,2004-03-10,20:00:00,2.2,1402.0,88.0,9.0,939,131.0,1140.0,114.0,1555.0,1074.0,11.9,54.0,0.7502
# 3          3,2004-03-10,21:00:00,2.2,1376.0,80.0,9.2,948,172.0,1092.0,122.0,1584.0,1203.0,11.0,60.0,0.7867
# 4          4,2004-03-10,22:00:00,1.6,1272.0,51.0,6.5,836,131.0,1205.0,116.0,1490.0,1110.0,11.2,59.6,0.7888
# 5             5,2004-03-10,23:00:00,1.2,1197.0,38.0,4.7,750,89.0,1337.0,96.0,1393.0,949.0,11.2,59.2,0.7848
# 6             6,2004-03-11,00:00:00,1.2,1185.0,31.0,3.6,690,62.0,1462.0,77.0,1333.0,733.0,11.3,56.8,0.7603
# 7             7,2004-03-11,01:00:00,1.0,1136.0,31.0,3.3,672,62.0,1453.0,76.0,1333.0,730.0,10.7,60.0,0.7702
# ...

# %%
 df.to_csv(r"C:\Users\Dell\Desktop\Panda\AirQualityUCI.csv")

# %%
df.head(10)
# Out:
#   ,Date,Time,CO,PT08_CO,NMHC,C6H6,PT08_NMHC,NOx,PT08_NOx,NO2,PT08_NO2,PT08_O3,T,RH,AH
# 0  0,2004-03-10,18:00:00,2.6,1360.0,150.0,11.9,10...
# 1  1,2004-03-10,19:00:00,2.0,1292.0,112.0,9.4,955...
# 2  2,2004-03-10,20:00:00,2.2,1402.0,88.0,9.0,939,...
# 3  3,2004-03-10,21:00:00,2.2,1376.0,80.0,9.2,948,...
# 4  4,2004-03-10,22:00:00,1.6,1272.0,51.0,6.5,836,...
# 5  5,2004-03-10,23:00:00,1.2,1197.0,38.0,4.7,750,...
# 6  6,2004-03-11,00:00:00,1.2,1185.0,31.0,3.6,690,...
# 7  7,2004-03-11,01:00:00,1.0,1136.0,31.0,3.3,672,...
# 8  8,2004-03-11,02:00:00,0.9,1094.0,24.0,2.3,609,...
# 9  11,2004-03-11,05:00:00,0.7,1066.0,8.0,1.1,512,...

# %%
df.describe()
# Out:
#        ,Date,Time,CO,PT08_CO,NMHC,C6H6,PT08_NMHC,NOx,PT08_NOx,NO2,PT08_NO2,PT08_O3,T,RH,AH
# count                                                 827
# unique                                                827
# top     0,2004-03-10,18:00:00,2.6,1360.0,150.0,11.9,10...
# freq                                                    1

# %%
#df.shape
# Out:
# (827, 1)

# %%
df.isnull().sum()
# Out:
# ,Date,Time,CO,PT08_CO,NMHC,C6H6,PT08_NMHC,NOx,PT08_NOx,NO2,PT08_NO2,PT08_O3,T,RH,AH    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# ,Date,Time,CO,PT08_CO,NMHC,C6H6,PT08_NMHC,NOx,PT08_NOx,NO2,PT08_NO2,PT08_O3,T,RH,AH    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 827 entries, 0 to 826
# Data columns (total 1 columns):
#  #   Column                                                                               Non-Null Count  Dtype
# ---  ------                                                                               --------------  -----
#  0   ,Date,Time,CO,PT08_CO,NMHC,C6H6,PT08_NMHC,NOx,PT08_NOx,NO2,PT08_NO2,PT08_O3,T,RH,AH  827 non-null    object
# dtypes: object(1)
# memory usage: 6.6+ KB

# %%
#df["Date"]=pd.to_datetime(df["Date"],dayfirst=True)
#df["Time"]=pd.to_datetime(df["Time"],format= '%H.%M.%S' ).dt.time

# %%
df['CO'] = df['CO'].astype(float)
df['C6H6'] = df['C6H6'].astype(float)
df['T'] = df['T'].astype(float)
df['RH'] = df['RH'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CO'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df['PT08_CO'] = df['PT08_CO'].astype(float)
df['NMHC'] = df['NMHC'].astype(float)
df['NOx'] = df['NOx'].astype(float)
df['PT08_NOx'] = df['PT08_NOx'].astype(float)
df['NO2'] = df['NO2'].astype(float)
df['PT08_NO2'] = df['PT08_NO2'].astype(float)
df['PT08_O3'] = df['PT08_O3'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PT08_CO'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df['AH'] = df['AH'].astype(float)
df['PT08_NMHC'] = df['PT08_NMHC'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'AH'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
#df.to_csv(r"C:\Users\Dell\Desktop\Panda\AirQualityUCI.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 827 entries, 0 to 826
# Data columns (total 1 columns):
#  #   Column                                                                               Non-Null Count  Dtype
# ---  ------                                                                               --------------  -----
#  0   ,Date,Time,CO,PT08_CO,NMHC,C6H6,PT08_NMHC,NOx,PT08_NOx,NO2,PT08_NO2,PT08_O3,T,RH,AH  827 non-null    object
# dtypes: object(1)
# memory usage: 6.6+ KB

# %%
df.head(10)
# Out:
#   ,Date,Time,CO,PT08_CO,NMHC,C6H6,PT08_NMHC,NOx,PT08_NOx,NO2,PT08_NO2,PT08_O3,T,RH,AH
# 0  0,2004-03-10,18:00:00,2.6,1360.0,150.0,11.9,10...
# 1  1,2004-03-10,19:00:00,2.0,1292.0,112.0,9.4,955...
# 2  2,2004-03-10,20:00:00,2.2,1402.0,88.0,9.0,939,...
# 3  3,2004-03-10,21:00:00,2.2,1376.0,80.0,9.2,948,...
# 4  4,2004-03-10,22:00:00,1.6,1272.0,51.0,6.5,836,...
# 5  5,2004-03-10,23:00:00,1.2,1197.0,38.0,4.7,750,...
# 6  6,2004-03-11,00:00:00,1.2,1185.0,31.0,3.6,690,...
# 7  7,2004-03-11,01:00:00,1.0,1136.0,31.0,3.3,672,...
# 8  8,2004-03-11,02:00:00,0.9,1094.0,24.0,2.3,609,...
# 9  11,2004-03-11,05:00:00,0.7,1066.0,8.0,1.1,512,...

# %%
df['CO'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CO'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.replace(to_replace=-200,value=pd.NA,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 827 entries, 0 to 826
# Data columns (total 1 columns):
#  #   Column                                                                               Non-Null Count  Dtype
# ---  ------                                                                               --------------  -----
#  0   ,Date,Time,CO,PT08_CO,NMHC,C6H6,PT08_NMHC,NOx,PT08_NOx,NO2,PT08_NO2,PT08_O3,T,RH,AH  827 non-null    object
# dtypes: object(1)
# memory usage: 6.6+ KB

# %%
df.dropna(inplace=True)

# %%
df['CO'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CO'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
data=df.drop(["Date","Time"],axis=1)
correlation=data.corr()
plt.figure(figsize=(12,8))
sns.heatmap(correlation,annot=True,cmap="coolwarm",fmt=".2f")
plt.title("Correlation Matrix")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 data=df.drop(["Date","Time"],axis=1)
#       2 correlation=data.corr()
#       3 plt.figure(figsize=(12,8))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
# ...

# %%
data=df.drop(["Date","Time"],axis=1)
data.corr()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 data=df.drop(["Date","Time"],axis=1)
#       2 data.corr()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
# ...

# %%
plt.figure(figsize=(30,10))
df['Time'] = df['Time'].astype(str)
sns.scatterplot(x="Time",y="CO",data=df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Time'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
plt.figure(figsize=(30,10))
df['Time'] = df['Time'].astype(str)
sns.scatterplot(x="Time",y="NMHC",data=df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Time'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
plt.figure(figsize=(30,15))
df['Time'] = df['Time'].astype(str)
sns.scatterplot(x="Time",y="C6H6",data=df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Time'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
plt.figure(figsize=(30,15))
df['Time'] = df['Time'].astype(str)
sns.scatterplot(x="Time",y="NOx",data=df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Time'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
plt.figure(figsize=(30,15))
df['Time'] = df['Time'].astype(str)
sns.scatterplot(x="Time",y="NO2",data=df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Time'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
"""CO level is highest at 8 am  in morning and 7 to 8pm at night.

NhMC level is highest at 8 am in morning and 7 pm at night.


C6H6 level is highest at 8 to 9 am in morning and 7 pm at night.


NOx level is highest at 9 am in morning and 7 pm at night.


NO2 level is highest at 3 pm in evening and 7 pm at night.

# Recomendations
1-Almost all of the parameters are at peak level in morning from 8 to 9 and at 7 pm at night .
At these hours there is a lot of traffic of schools , factories, offices so it is clear that to
improve air quality we should control the traffic at these hours
"""
# Out:
# 'CO level is highest at 8 am  in morning and 7 to 8pm at night.\n\nNhMC level is highest at 8 am in morning and 7 pm at night.\n\n\nC6H6 level is highest at 8 to 9 am in morning and 7 pm at night.\n\n\nNOx level is highest at 9 am in morning and 7 pm at night.\n\n\nNO2 level is highest at 3 pm in evening and 7 pm at night.\n\n# Recomendations\n1-Almost all of the parameters are at peak level in morning from 8 to 9 and at 7 pm at night .\nAt these hours there is a lot of traffic of schools , factories, offices so it is clear that to\nimprove air quality we should control the traffic at these hours\n'
